# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import os

# %%
# Step 1: Define paths and parameters
data_dir = r'C:\Users\Admin\Desktop\CNN Project\waste-classification-main\waste-classification-main\dataset-resized'  # Replace with the path to your dataset
categories = ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']
img_size = (128, 128)
batch_size = 32

# Step 2: Data Augmentation and Preprocessing
data_gen = ImageDataGenerator(
    rescale=1./255,  # Normalize pixel values
    rotation_range=40,  # Random rotation
    width_shift_range=0.2,  # Horizontal shift
    height_shift_range=0.2,  # Vertical shift
    shear_range=0.2,  # Shear transformation
    zoom_range=0.2,  # Random zoom
    horizontal_flip=True,  # Horizontal flipping
    fill_mode='nearest',
    validation_split=0.2  # 20% data for validation
)

train_data = data_gen.flow_from_directory(
    data_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

val_data = data_gen.flow_from_directory(
    data_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)

# Step 2.1: Compute Class Weights
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

class_labels = train_data.classes
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(class_labels),
    y=class_labels
)

class_weights = dict(enumerate(class_weights))
# Out:
# Found 2024 images belonging to 6 classes.
# Found 503 images belonging to 6 classes.

# %%
# Step 3: Build the Model using Transfer Learning
base_model = tf.keras.applications.MobileNetV2(input_shape=(128, 128, 3), include_top=False, weights='imagenet')
base_model.trainable = True  # Freeze base layers

# Freeze earlier layers, fine-tune only the last 50 layers
for layer in base_model.layers[:-50]:
    layer.trainable = False


model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    Dropout(0.6),
    Dense(len(categories), activation='softmax')
])

# Step 4: Compile the Model
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.0001,  # Lower learning rate for fine-tuning
    decay_steps=10000,
    decay_rate=0.9
)
optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Step 5: Train the Model
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
history = model.fit(
    train_data,
    epochs=50,
    validation_data=val_data,
    callbacks=[early_stopping],
    class_weight=class_weights  # Apply class weights
)
# Step 6: Save the Model
model.save(r'C:\Users\Admin\Desktop\CNN Project\waste-classification-main\waste-classification-main/waste_classification_model.h5')
# Out:
# c:\Users\Admin\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 64s 802ms/step - accuracy: 0.3350 - loss: 4.1980 - val_accuracy: 0.4533 - val_loss: 3.7026
# Epoch 2/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 33s 511ms/step - accuracy: 0.5415 - loss: 3.4713 - val_accuracy: 0.4632 - val_loss: 3.7034
# Epoch 3/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 32s 503ms/step - accuracy: 0.6418 - loss: 3.1717 - val_accuracy: 0.4493 - val_loss: 3.7063
# Epoch 4/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 500ms/step - accuracy: 0.7016 - loss: 2.9808 - val_accuracy: 0.4950 - val_loss: 3.5299
# Epoch 5/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 32s 505ms/step - accuracy: 0.7416 - loss: 2.8333 - val_accuracy: 0.5626 - val_loss: 3.4542
# Epoch 6/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 33s 509ms/step - accuracy: 0.7757 - loss: 2.6919 - val_accuracy: 0.5368 - val_loss: 3.5010
# Epoch 7/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 501ms/step - accuracy: 0.8039 - loss: 2.5639 - val_accuracy: 0.5328 - val_loss: 3.7231
# Epoch 8/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 32s 496ms/step - accuracy: 0.8207 - loss: 2.4532 - val_accuracy: 0.5249 - val_loss: 3.6032
# Epoch 9/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 497ms/step - accuracy: 0.8315 - loss: 2.3877 - val_accuracy: 0.6103 - val_loss: 3.1826
# Epoch 10/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 32s 503ms/step - accuracy: 0.8572 - loss: 2.2678 - val_accuracy: 0.5924 - val_loss: 3.2355
# Epoch 11/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 32s 501ms/step - accuracy: 0.8641 - loss: 2.1850 - val_accuracy: 0.6123 - val_loss: 3.1964
# Epoch 12/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 32s 496ms/step - accuracy: 0.8631 - loss: 2.1441 - val_accuracy: 0.6382 - val_loss: 2.9311
# Epoch 13/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 42s 505ms/step - accuracy: 0.8829 - loss: 2.0557 - val_accuracy: 0.6441 - val_loss: 2.8313
# Epoch 14/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 504ms/step - accuracy: 0.8878 - loss: 1.9807 - val_accuracy: 0.5984 - val_loss: 3.1702
# Epoch 15/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 32s 498ms/step - accuracy: 0.9012 - loss: 1.8772 - val_accuracy: 0.5726 - val_loss: 3.1267
# Epoch 16/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 37s 583ms/step - accuracy: 0.9056 - loss: 1.8259 - val_accuracy: 0.5885 - val_loss: 2.8982
# Epoch 17/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 35s 494ms/step - accuracy: 0.9056 - loss: 1.7819 - val_accuracy: 0.6561 - val_loss: 2.7374
# Epoch 18/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 490ms/step - accuracy: 0.9195 - loss: 1.7230 - val_accuracy: 0.6302 - val_loss: 2.8159
# Epoch 19/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 489ms/step - accuracy: 0.9224 - loss: 1.6482 - val_accuracy: 0.6421 - val_loss: 2.7097
# Epoch 20/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 39s 458ms/step - accuracy: 0.9269 - loss: 1.6059 - val_accuracy: 0.6581 - val_loss: 2.6359
# Epoch 21/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 42s 468ms/step - accuracy: 0.9279 - loss: 1.5626 - val_accuracy: 0.7038 - val_loss: 2.3731
# Epoch 22/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 464ms/step - accuracy: 0.9343 - loss: 1.4816 - val_accuracy: 0.7137 - val_loss: 2.2710
# Epoch 23/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 460ms/step - accuracy: 0.9461 - loss: 1.4327 - val_accuracy: 0.7237 - val_loss: 2.3371
# Epoch 24/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 454ms/step - accuracy: 0.9427 - loss: 1.3968 - val_accuracy: 0.7535 - val_loss: 2.0559
# Epoch 25/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 42s 465ms/step - accuracy: 0.9511 - loss: 1.3209 - val_accuracy: 0.7634 - val_loss: 2.0871
# Epoch 26/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 465ms/step - accuracy: 0.9506 - loss: 1.2876 - val_accuracy: 0.7793 - val_loss: 1.9539
# Epoch 27/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 465ms/step - accuracy: 0.9550 - loss: 1.2236 - val_accuracy: 0.7416 - val_loss: 1.9947
# Epoch 28/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 464ms/step - accuracy: 0.9506 - loss: 1.1956 - val_accuracy: 0.6799 - val_loss: 2.2892
# Epoch 29/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 464ms/step - accuracy: 0.9536 - loss: 1.1656 - val_accuracy: 0.7674 - val_loss: 1.8514
# Epoch 30/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 464ms/step - accuracy: 0.9625 - loss: 1.1031 - val_accuracy: 0.7654 - val_loss: 1.9537
# Epoch 31/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 461ms/step - accuracy: 0.9545 - loss: 1.0885 - val_accuracy: 0.7078 - val_loss: 2.1368
# Epoch 32/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 464ms/step - accuracy: 0.9545 - loss: 1.0391 - val_accuracy: 0.7495 - val_loss: 1.8798
# Epoch 33/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 468ms/step - accuracy: 0.9605 - loss: 1.0017 - val_accuracy: 0.7217 - val_loss: 1.9707
# Epoch 34/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 42s 478ms/step - accuracy: 0.9471 - loss: 1.0028 - val_accuracy: 0.7356 - val_loss: 1.7742
# Epoch 35/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 40s 459ms/step - accuracy: 0.9644 - loss: 0.9335 - val_accuracy: 0.7455 - val_loss: 1.8002
# Epoch 36/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 458ms/step - accuracy: 0.9620 - loss: 0.8944 - val_accuracy: 0.7256 - val_loss: 1.8386
# Epoch 37/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 458ms/step - accuracy: 0.9699 - loss: 0.8570 - val_accuracy: 0.7495 - val_loss: 1.7556
# Epoch 38/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 42s 473ms/step - accuracy: 0.9565 - loss: 0.8436 - val_accuracy: 0.7535 - val_loss: 1.6716
# Epoch 39/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 467ms/step - accuracy: 0.9743 - loss: 0.7886 - val_accuracy: 0.7833 - val_loss: 1.5622
# Epoch 40/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 466ms/step - accuracy: 0.9644 - loss: 0.7721 - val_accuracy: 0.7058 - val_loss: 1.8699
# Epoch 41/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 471ms/step - accuracy: 0.9654 - loss: 0.7670 - val_accuracy: 0.7276 - val_loss: 1.7407
# Epoch 42/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 468ms/step - accuracy: 0.9674 - loss: 0.7226 - val_accuracy: 0.7694 - val_loss: 1.5158
# Epoch 43/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 466ms/step - accuracy: 0.9679 - loss: 0.7059 - val_accuracy: 0.7197 - val_loss: 1.8358
# Epoch 44/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 30s 465ms/step - accuracy: 0.9768 - loss: 0.6580 - val_accuracy: 0.6620 - val_loss: 1.8918
# Epoch 45/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 466ms/step - accuracy: 0.9807 - loss: 0.6103 - val_accuracy: 0.6938 - val_loss: 1.8277
# Epoch 46/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 465ms/step - accuracy: 0.9733 - loss: 0.6153 - val_accuracy: 0.6918 - val_loss: 1.8773
# Epoch 47/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 457ms/step - accuracy: 0.9758 - loss: 0.5877 - val_accuracy: 0.7217 - val_loss: 1.8828
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Step 7: Evaluate the Model
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Step 8: Test the Model (Optional)
def predict_image(image_path):
    from tensorflow.keras.utils import load_img, img_to_array
    import numpy as np

    img = load_img(image_path, target_size=img_size)  # Load image with specified size
    img_array = img_to_array(img) / 255.0  # Normalize the image
    img_array = tf.expand_dims(img_array, 0)  # Expand dimensions to match model input
    
    predictions = model.predict(img_array)  # Get predictions
    class_idx = tf.argmax(predictions[0]).numpy()  # Get class index
    class_label = categories[class_idx]  # Map to class label
    return class_label

# Test with a sample image
sample_image_path = r"C:\Users\Admin\Desktop\CNN Project\waste-classification-main\waste-classification-main\dataset-resized\metal\metal5.jpg"  # Replace with an actual image path
print("Predicted Class:", predict_image(sample_image_path))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 941ms/step
# Predicted Class: metal
